# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# make sure you're on a GPU runtime in Colab:
# Runtime > change runtime type > GPU

# !nvidia-smi
# Out:
# Fri Apr  3 21:50:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# clone with https, not ssh
# !git clone https://github.com/VIDA-NYU/tile2net.git
# %cd /content/tile2net

# install compatible numpy first
# !pip install --no-cache-dir "numpy<2"

# install repo
# !pip install --no-cache-dir -e .
# Out:
# fatal: destination path 'tile2net' already exists and is not an empty directory.
# /content/tile2net
# ...
# Obtaining file:///content/tile2net
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 99.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 150.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 251.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 363.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 388.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 341.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 353.8 MB/s eta 0:00:00
# ...

# %%
import sys
sys.path.insert(0, "/content/tile2net/src")

# %%
# Test
from tile2net import Raster
print("Setup complete")
# Out:
# Setup complete

# %%
location = "37.84689387124369, -122.29514809880816, 37.884805251644806, -122.25070602691783"

# top right corner: 37.884805251644806, -122.25070602691783
# bottom left: 37.84689387124369, -122.29514809880816

raster = Raster(
    location=location,
    name="Berkeley",
    output_dir="/content/drive/MyDrive/255 Final Project/Data/Tile2Net",
)

raster
# Out:
# INFO       Using AlamedaCounty as the source at location=(37.8468938712, -122.2951480988, 37.8848052516, -122.2507060269)
# INFO       Using zoom=20 from source
# INFO       Using base_tilesize=256 from source
# Berkeley Data Constructor.
# Coordinate reference system (CRS): 4326
# Tile size (pixel): 256
# Zoom level: 20
# Number of columns: 131
# Number of rows: 141
# Total tiles: 18,471

# %%
raster.generate(4)
raster.inference()
# Out:
# INFO       Stitching 131 tiles...
# ...
# INFO       All 19008 tiles are on disk.
# INFO       All tiles already stitched.
# INFO       Dumping to /content/drive/MyDrive/255 Final Project/Data/Tile2Net/Berkeley/tiles/Berkeley_256_info.json
# {
#     "config": "/content/tile2net/src/tile2net/tileseg/config.py",
#     "assets": {
#         "weights": {
#             "satellite_2021": "/content/tile2net/src/tile2net/raster/resources/assets/weights/satellite_2021.pth",
#             "hrnetv2_w48_imagenet_pretrained": "/content/tile2net/src/tile2net/raster/resources/assets/weights/hrnetv2_w48_imagenet_pretrained.pth"
#         }
#     },
#     "segmentation": "/content/drive/MyDrive/255 Final Project/Data/Tile2Net/Berkeley/segmentation/Berkeley/256_20_4",
#     "tiles": {
#         "info": "/content/drive/MyDrive/255 Final Project/Data/Tile2Net/Berkeley/tiles/Berkeley_256_info.json",
#         "static": "/content/drive/MyDrive/255 Final Project/Data/Tile2Net/Berkeley/tiles/static/al/256_20",
# ...
